# %%
import pandas as pd 
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
path = 'data/products_all_brands.csv' 
df = pd.read_csv(path) 
df.head()
# Out:
#                    product_name  product_id  beauty_point_earned  \
# 0       MULTI EYE COLOR PALETTE       97802                  130
# 1               VELVET LIP TINT       97810                   50
# 2                     LIP COLOR       97822                   60
# 3  MINI MULTI EYE COLOR PALETTE       97833                   80
# 4                    FACE BLUSH       97801                   60
#
#                price_range price_by_combinations  \
# 0  Rp 555.000 - Rp 687.000                   NaN
# 1               Rp 264.000                   NaN
# 2               Rp 317.000                   NaN
# 3               Rp 423.000                   NaN
# 4               Rp 300.000                   NaN
#
#                                                  url  \
# 0  https://www.sociolla.com/eyeshadow/69460-phan-...
# 1  https://www.sociolla.com/lip-cream/69468-son-k...
# 2  https://www.sociolla.com/lip-matte/69480-son-t...
# 3  https://www.sociolla.com/eyeshadow/69491-phan-...
# 4  https://www.sociolla.com/blush/69459-phan-ma-h...
#
#                 active_date default_category               categories  \
# 0  2022-10-03T03:30:06.681Z        Eyeshadow  Makeup; Eyes; Eyeshadow
# 1  2022-10-03T03:02:40.340Z        Lip Cream  Makeup; Lips; Lip Cream
# 2  2023-05-30T09:49:15.158Z         Lipstick   Makeup; Lips; Lipstick
# 3  2022-10-03T03:27:01.334Z        Eyeshadow  Makeup; Eyes; Eyeshadow
# 4  2022-10-03T03:22:26.610Z            Blush      Makeup; Face; Blush
#
#                                     rating_types_str  average_rating  \
# 0  is_star_long_wear;is_star_packaging;is_star_pi...        4.920000
# 1  is_star_long_wear;is_star_packaging;is_star_pi...        4.576190
# 2  is_star_long_wear;is_star_packaging;is_star_pi...        0.000000
# 3  is_star_long_wear;is_star_packaging;is_star_pi...        4.883333
# 4  is_star_long_wear;is_star_packaging;is_star_pi...        4.858824
#
#    total_reviews                            average_rating_by_types  \
# 0              5  "star_long_wear": 5; "star_packaging": 4.8; "s...
# 1             42  "star_long_wear": 4.309523809523809; "star_pac...
# 2              0                                                NaN
# 3              6  "star_long_wear": 4.916666666666667; "star_pac...
# 4             13  "star_long_wear": 4.9411764705882355; "star_pa...
#
#    total_recommended_count  total_repurchase_maybe_count  \
# 0                        5                             0
# 1                       42                            10
# 2                        0                             0
# 3                       12                             1
# 4                       17                             2
#
#    total_repurchase_no_count  total_repurchase_yes_count  total_in_wishlist
# 0                          0                           5                717
# 1                          2                          30                682
# 2                          0                           0                173
# 3                          0                          11                257
# 4                          0                          15                387

# %%
path = 'data/products_all_brands.csv'
df = pd.read_csv(path , index_col=['product_id'])
df.head()
# Out:
#                             product_name  beauty_point_earned  \
# product_id
# 97802            MULTI EYE COLOR PALETTE                  130
# 97810                    VELVET LIP TINT                   50
# 97822                          LIP COLOR                   60
# 97833       MINI MULTI EYE COLOR PALETTE                   80
# 97801                         FACE BLUSH                   60
#
#                         price_range price_by_combinations  \
# product_id
# 97802       Rp 555.000 - Rp 687.000                   NaN
# 97810                    Rp 264.000                   NaN
# 97822                    Rp 317.000                   NaN
# 97833                    Rp 423.000                   NaN
# 97801                    Rp 300.000                   NaN
#
#                                                           url  \
# product_id
# 97802       https://www.sociolla.com/eyeshadow/69460-phan-...
# 97810       https://www.sociolla.com/lip-cream/69468-son-k...
# 97822       https://www.sociolla.com/lip-matte/69480-son-t...
# 97833       https://www.sociolla.com/eyeshadow/69491-phan-...
# 97801       https://www.sociolla.com/blush/69459-phan-ma-h...
#
#                          active_date default_category  \
# product_id
# 97802       2022-10-03T03:30:06.681Z        Eyeshadow
# 97810       2022-10-03T03:02:40.340Z        Lip Cream
# 97822       2023-05-30T09:49:15.158Z         Lipstick
# 97833       2022-10-03T03:27:01.334Z        Eyeshadow
# 97801       2022-10-03T03:22:26.610Z            Blush
#
#                          categories  \
# product_id
# 97802       Makeup; Eyes; Eyeshadow
# 97810       Makeup; Lips; Lip Cream
# 97822        Makeup; Lips; Lipstick
# 97833       Makeup; Eyes; Eyeshadow
# 97801           Makeup; Face; Blush
#
#                                              rating_types_str  average_rating  \
# product_id
# 97802       is_star_long_wear;is_star_packaging;is_star_pi...        4.920000
# 97810       is_star_long_wear;is_star_packaging;is_star_pi...        4.576190
# 97822       is_star_long_wear;is_star_packaging;is_star_pi...        0.000000
# 97833       is_star_long_wear;is_star_packaging;is_star_pi...        4.883333
# 97801       is_star_long_wear;is_star_packaging;is_star_pi...        4.858824
#
#             total_reviews                            average_rating_by_types  \
# product_id
# 97802                   5  "star_long_wear": 5; "star_packaging": 4.8; "s...
# 97810                  42  "star_long_wear": 4.309523809523809; "star_pac...
# 97822                   0                                                NaN
# 97833                   6  "star_long_wear": 4.916666666666667; "star_pac...
# 97801                  13  "star_long_wear": 4.9411764705882355; "star_pa...
#
#             total_recommended_count  total_repurchase_maybe_count  \
# product_id
# 97802                             5                             0
# 97810                            42                            10
# 97822                             0                             0
# 97833                            12                             1
# 97801                            17                             2
#
#             total_repurchase_no_count  total_repurchase_yes_count  \
# product_id
# 97802                               0                           5
# 97810                               2                          30
# 97822                               0                           0
# 97833                               0                          11
# 97801                               0                          15
#
#             total_in_wishlist
# product_id
# 97802                     717
# 97810                     682
# 97822                     173
# 97833                     257
# 97801                     387

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7636 entries, 97802 to 64153
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   product_name                  7636 non-null   object
#  1   beauty_point_earned           7636 non-null   int64
#  2   price_range                   7636 non-null   object
#  3   price_by_combinations         4087 non-null   object
#  4   url                           7636 non-null   object
#  5   active_date                   5534 non-null   object
#  6   default_category              7636 non-null   object
#  7   categories                    7632 non-null   object
#  8   rating_types_str              7561 non-null   object
#  9   average_rating                7636 non-null   float64
#  10  total_reviews                 7636 non-null   int64
#  11  average_rating_by_types       5790 non-null   object
#  12  total_recommended_count       7636 non-null   int64
#  13  total_repurchase_maybe_count  7636 non-null   int64
#  14  total_repurchase_no_count     7636 non-null   int64
#  15  total_repurchase_yes_count    7636 non-null   int64
#  16  total_in_wishlist             7636 non-null   int64
# dtypes: float64(1), int64(7), object(9)
# memory usage: 1.0+ MB

# %%
df.drop(columns='price_by_combinations',inplace=True)

# %%
df.drop(columns='url',inplace=True)

# %%
df.drop(columns='active_date',inplace=True)

# %%
df.drop(columns='rating_types_str',inplace=True)

# %%
df.drop(columns='average_rating_by_types',inplace=True)

# %%
df
# Out:
#                             product_name  beauty_point_earned  \
# product_id
# 97802            MULTI EYE COLOR PALETTE                  130
# 97810                    VELVET LIP TINT                   50
# 97822                          LIP COLOR                   60
# 97833       MINI MULTI EYE COLOR PALETTE                   80
# 97801                         FACE BLUSH                   60
# ...                                  ...                  ...
# 2158          Ambre Noir Eau De Toilette                  130
# 64174       Soin Stimulating Conditioner                   30
# 36357                   Repair Hair Mask                   50
# 36404        Hand Cream Olive Petitgrain                   20
# 64153                         Color Mask                   50
#
#                         price_range   default_category  \
# product_id
# 97802       Rp 555.000 - Rp 687.000          Eyeshadow
# 97810                    Rp 264.000          Lip Cream
# 97822                    Rp 317.000           Lipstick
# 97833                    Rp 423.000          Eyeshadow
# 97801                    Rp 300.000              Blush
# ...                             ...                ...
# 2158                     Rp 659.000    Eau De Toilette
# 64174                    Rp 199.000        Conditioner
# 36357                    Rp 289.000          Hair Mask
# 36404                    Rp 109.000  Hand & Foot Cream
# 64153                    Rp 289.000          Hair Mask
#
#                                                   categories  average_rating  \
# product_id
# 97802                                Makeup; Eyes; Eyeshadow        4.920000
# 97810                                Makeup; Lips; Lip Cream        4.576190
# 97822                                 Makeup; Lips; Lipstick        0.000000
# 97833                                Makeup; Eyes; Eyeshadow        4.883333
# 97801                                    Makeup; Face; Blush        4.858824
# ...                                                      ...             ...
# 2158                       Shop By Departments; Home; UOBMon        4.476190
# 64174                        Hair Care; Shampoo; Conditioner        4.638889
# 36357                   Hair Care; Hair Treatment; Hair Mask        4.750000
# 36404       Shop By Departments; Home; 12.12 PRICE POINT 50%        4.968750
# 64153                   Hair Care; Hair Treatment; Hair Mask        4.500000
#
#             total_reviews  total_recommended_count  \
# product_id
# 97802                   5                        5
# 97810                  42                       42
# 97822                   0                        0
# 97833                   6                       12
# 97801                  13                       17
# ...                   ...                      ...
# 2158                    7                        6
# 64174                   9                        7
# 36357                   5                        5
# 36404                   8                        8
# 64153                   2                        2
#
#             total_repurchase_maybe_count  total_repurchase_no_count  \
# product_id
# 97802                                  0                          0
# 97810                                 10                          2
# 97822                                  0                          0
# 97833                                  1                          0
# 97801                                  2                          0
# ...                                  ...                        ...
# 2158                                   1                          2
# 64174                                  1                          2
# 36357                                  1                          0
# 36404                                  2                          0
# 64153                                  1                          0
#
#             total_repurchase_yes_count  total_in_wishlist
# product_id
# 97802                                5                717
# 97810                               30                682
# 97822                                0                173
# 97833                               11                257
# 97801                               15                387
# ...                                ...                ...
# 2158                                 4                355
# 64174                                6                122
# 36357                                4                 58
# 36404                                6                117
# 64153                                1                 35
#
# [7636 rows x 12 columns]
